# %%
configs = {"fs.adl.oauth2.access.token.provider.type": "ClientCredential",
           "fs.adl.oauth2.client.id": "acdb7f51-a741-4e7b-90cc-0bebc6c8cf94",
           "fs.adl.oauth2.credential": dbutils.secrets.get(scope = "ADBAccess", key = "ADLKey"),
           "fs.adl.oauth2.refresh.url": "https://login.microsoftonline.com/662909ff-6e3b-44d0-99d4-f0f2ecd1ef4e/oauth2/token"}

# Optionally, you can add <directory-name> to the source URI of your mount point.
dbutils.fs.mount(
  source = "adl://mslabstorage.azuredatalakestore.net/Output7",
  mount_point = "/mnt/adlsmounto7",
  extra_configs = configs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: True</div>

# %%
#%run users/infy_797967@outlook.com/ADLS Mount
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dfDimDisease = spark.read.format("com.databricks.spark.csv").options(header="true",inferschema="true").load("mnt/adlsmounto7/Products")
#dfDimDisease.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">IllegalArgumentException</span>                  Traceback (most recent call last)
# ...

# %%
dbutils.fs.ls("mnt/adlsmount")

# %%
 sparkDF = spark.read.format("com.crealytics.spark.excel").option("Header", "true").option("inferSchema", "true").load("/mnt/Patient_Dimension.xlsx")

# %%
 df = spark.read.format("org.zuinnote.spark.office.excel").option("read.spark.useHeader", "true").load("/mnt/Patient_Dimension.xlsx")

# %%
 df_excel= spark.read. format("com.crealytics.spark.excel"). option("Header", "true"). option("treatEmptyValuesAsNulls", "false"). option("inferSchema", "false"). option("addColorColumns", "false").load("/mnt/Patient_Dimension") 
display(df_excel)
