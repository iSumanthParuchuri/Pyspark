# %%
emp1 = spark.read.parquet('/mnt/ADFandADBHands-on/employees1.parquet')
emp2 = spark.read.parquet('/mnt/ADFandADBHands-on/employees2.parquet')
emp3 = spark.read.parquet('/mnt/ADFandADBHands-on/employees3.parquet')
emp4 = spark.read.parquet('/mnt/ADFandADBHands-on/employees4.parquet')
emp5 = spark.read.parquet('/mnt/ADFandADBHands-on/employees5.parquet')
emp6 = spark.read.parquet('/mnt/ADFandADBHands-on/employees6.parquet')
emp=[emp1,emp2,emp3,emp4,emp5,emp6]
final=emp1
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(emp)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[DataFrame[ID: string, Name: string, Department: string, Manager: string, Salary: string], DataFrame[ID: string, Name: string, Department: string, Manager: string, Salary: string], DataFrame[ID: string, Name: string, Department: string, Manager: string, Salary: string], DataFrame[ID: string, Name: string, Department: string, Manager: string, Salary: string], DataFrame[ID: string, Name: string, Department: string, Manager: string, Salary: string], DataFrame[ID: string, Name: string, Department: string, Manager: string, Salary: string]]
# </div>

# %%
emp_csv = spark.read.options(header="true").csv('/mnt/adlsmounto7/Products.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
emp_csv.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+---------------------------+---+--------+---+
# P101|Lamborghini Gallardo Spyder|  1|18000000| 10|
# +----+---------------------------+---+--------+---+
# P102|                     BMW X1|  1| 3390000| 10|
# P103|                     BMW Z4|  1| 6890000| 10|
# P104|       Harley Davidson I...|  1|  700000| 10|
# P105|         Ducati Multistrada|  1| 2256000| 10|
# P106|             Honda CBR 250R|  1|  193000|100|
# P107|       Kenneth Cole Blac...|  2|    2500| 50|
# P108|       Classic Brooks Br...|  2|    3079| 10|
# P109|       Ben Sherman Mens ...|  2|    1847| 20|
# P110|       BRIONI Shirt Cott...|  2|    2050| 25|
# ...
